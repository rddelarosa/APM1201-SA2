# %% [markdown]
# # <h1> <b> <center> FA 10</center>  </b> </h1>

# %% [markdown]
#  <h3> <b> <center> 1. Import the necessary libraries such as pandas, numpy, matplotlib, and seaborn.
#
#  </center>  </b> </h3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tabulate
import os

# !gdown --id "1wBuOcjOx8NPqalrQRCmzKSseoI9QHYQ_" -O data.csv

if os.path.exists("data.csv"):
    data = pd.read_csv("data.csv")
else:
    print("File download failed.")
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1wBuOcjOx8NPqalrQRCmzKSseoI9QHYQ_
# To: /content/data.csv
# 100% 30.8M/30.8M [00:00<00:00, 118MB/s]

# %% [markdown]
#  <h3> <b> <center> 2. Display the first 10 rows of the data </center>  </b> </h3>

# %%
data.head(10)
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 5           5  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 6           6  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 7           7  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 8           8  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 9           9  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                                Track  \
# 0                                     Feel Good Inc.
# ...

# %% [markdown]
#  <h3> <b> <center>3. Check and display the column names </center>  </b> </h3>

# %%
for column in data:
    print(column)
# Out:
# Unnamed: 0
# Artist
# Url_spotify
# Track
# Album
# Album_type
# Uri
# Danceability
# Energy
# Key
# Loudness
# Speechiness
# Acousticness
# Instrumentalness
# Liveness
# Valence
# Tempo
# Duration_ms
# Url_youtube
# Title
# Channel
# Views
# Likes
# Comments
# Description
# Licensed
# official_video
# Stream

# %% [markdown]
#  <h3> <b> <center> 4. Display the info of the dataset and make description of the column counts, number of data points, some columns that contain null values, and the datatypes counts. </center>  </b> </h3>

# %%
# Display Dataset Info with additional details
print(f"\nDataset Info: {data.info()}")
print(f"\nColumn Counts: {len(data.columns)}")
print(f"\nNumber of Data Points:{len(data)}")
print(f"\nColumns with Null Values: {data.columns[data.isnull().any()].tolist()}")
print(f"\nData Type Counts:\n{data.dtypes.value_counts()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20718 non-null  int64
#  1   Artist            20718 non-null  object
#  2   Url_spotify       20718 non-null  object
#  3   Track             20718 non-null  object
#  4   Album             20718 non-null  object
#  5   Album_type        20718 non-null  object
#  6   Uri               20718 non-null  object
#  7   Danceability      20716 non-null  float64
#  8   Energy            20716 non-null  float64
#  9   Key               20716 non-null  float64
#  10  Loudness          20716 non-null  float64
#  11  Speechiness       20716 non-null  float64
#  12  Acousticness      20716 non-null  float64
#  13  Instrumentalness  20716 non-null  float64
#  14  Liveness          20716 non-null  float64
#  15  Valence           20716 non-null  float64
# ...

# %% [markdown]
#  <h3> <b> <center> 5. Fill NA in likes with 0, NA in comments with 0, and drop others. </center>  </b> </h3>

# %%
data['Likes'].fillna(0, inplace=True)
data['Comments'].fillna(0, inplace=True)
data.dropna(inplace=True)

# %% [markdown]
#  <h3> <b> <center> 6. Describe (descriptive measures: count, mean, std, min, 25%, 50%, 75%, max) the cleaned data. </center>  </b> </h3>

# %%
numerical_description = data.describe()

categorical_description = data.describe(include='object')
print("Numerical Columns Description:")
print(tabulate(numerical_description, headers='keys', tablefmt='mixed_grid'))

print("\nCategorical Columns Description:")
print(tabulate(categorical_description, headers='keys', tablefmt='mixed_grid'))
# Out:
# Numerical Columns Description:
# ┍━━━━━━━┯━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━┯━━━━━━━━━━━━━┯━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━┯━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━┑
# │       │   Unnamed: 0 │   Danceability │       Energy │         Key │    Loudness │   Speechiness │   Acousticness │   Instrumentalness │     Liveness │      Valence │     Tempo │      Duration_ms │           Views │            Likes │         Comments │          Stream │
# ┝━━━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━━━━━━┿━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━┿━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┥
# ...

# %% [markdown]
#  <h3> <b> <center> 7. Explore album type and display counts for album, single, and compilation. </center>  </b> </h3>

# %%
album_counts.index = album_counts.index.str.capitalize()
album_counts_table = tabulate(pd.DataFrame(album_counts), headers=['Album Type', 'Count'], tablefmt='mixed_grid')
print(album_counts_table)
# Out:
# ┍━━━━━━━━━━━━━━┯━━━━━━━━━┑
# │ Album Type   │   Count │
# ┝━━━━━━━━━━━━━━┿━━━━━━━━━┥
# │ Album        │   13952 │
# ├──────────────┼─────────┤
# │ Single       │    4653 │
# ├──────────────┼─────────┤
# │ Compilation  │     693 │
# ┕━━━━━━━━━━━━━━┷━━━━━━━━━┙

# %% [markdown]
#  <h3> <b> <center> 8. Create a pie chart for Album Types as a Title and make some remarks. </center>  </b> </h3>

# %%
# Pie chart
plt.pie(album_counts, labels=album_counts.index, autopct='%1.1f%%')
plt.title('Album Types')
plt.show()

# %% [markdown]
#  <h3> <b> <center> 9. Analyze songs by artist and views-youtube, stream-spotify. </center>  </b> </h3>

# %%
def format_number(num):
    if num >= 1e9:
        return f'{num / 1e9:.2f}B'
    elif num >= 1e6:
        return f'{num / 1e6:.2f}M'
    else:
        return str(num)

artist_youtube = data.groupby('Artist')['Views'].sum()
artist_spotify = data.groupby('Artist')['Stream'].sum()

artist_data = pd.DataFrame({'YouTube Views': artist_youtube, 'Spotify Streams': artist_spotify})

artist_data.reset_index(inplace=True)

artist_data = artist_data.sort_values(by='YouTube Views', ascending=False)

artist_data['YouTube Views'] = artist_data['YouTube Views'].apply(format_number)
artist_data['Spotify Streams'] = artist_data['Spotify Streams'].apply(format_number)

print(tabulate(artist_data, headers='keys', tablefmt='mixed_grid', showindex=False))
# Out:
# ┍━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━┑
# │ Artist                                        │ YouTube Views   │ Spotify Streams   │
# ┝━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┥
# │ Ed Sheeran                                    │ 15.46B          │ 14.39B            │
# ├───────────────────────────────────────────────┼─────────────────┼───────────────────┤
# │ CoComelon                                     │ 14.60B          │ 369.08M           │
# ├───────────────────────────────────────────────┼─────────────────┼───────────────────┤
# │ Katy Perry                                    │ 13.12B          │ 6.61B             │
# ├───────────────────────────────────────────────┼─────────────────┼───────────────────┤
# │ Charlie Puth                                  │ 12.17B          │ 7.04B             │
# ├───────────────────────────────────────────────┼─────────────────┼───────────────────┤
# ...

# %% [markdown]
# <h3> <b> <center> 10. Create bar charts for Top 10 Artists on Youtube and Top 10 Artists on Spotify in 1 row of display. </center>  </b> </h3>

# %%
# Get the top 10 artists on YouTube and their total stream counts
top_10_youtube_artists = data.groupby('Artist')['Stream'].sum().nlargest(10)
top_10_spotify_artists = data.groupby('Artist')['Views'].sum().nlargest(10)

spotify_streams_youtube = data[data['Artist'].isin(top_10_youtube_artists.index)].groupby('Artist')['Views'].sum()
youtube_streams_spotify = data[data['Artist'].isin(top_10_spotify_artists.index)].groupby('Artist')['Stream'].sum()

combined_streams_youtube = pd.DataFrame({'YouTube Streams': top_10_youtube_artists, 'Spotify Streams': spotify_streams_youtube})
combined_streams_spotify = pd.DataFrame({'Spotify Streams': top_10_spotify_artists, 'YouTube Streams': youtube_streams_spotify})

combined_streams_youtube_sorted = combined_streams_youtube.sort_values(by='YouTube Streams', ascending=False)
combined_streams_spotify_sorted = combined_streams_spotify.sort_values(by='Spotify Streams', ascending=False)

fig, axs = plt.subplots(1, 2, figsize=(15, 6))

# Plot the top 10 artists on YouTube
combined_streams_youtube_sorted.plot(kind='bar', ax=axs[0])
axs[0].set_title('Top 10 Artists on Spotify')
axs[0].set_ylabel('Stream Counts')
axs[0].set_xlabel('Artist')

# Plot the top 10 artists on Spotify
combined_streams_spotify_sorted.plot(kind='bar', ax=axs[1])
axs[1].set_title('Top 10 Artists on Youtube')
axs[1].set_ylabel('Stream Counts')
axs[1].set_xlabel('Artist')

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
#  <h3> <b> <center> 11. Make some remarks about the Top 10 Artists on Youtube and Top 10 Artists on Spotify. </center>  </b> </h3>

# %% [markdown]
# It's interesting to observe the differences and similarities between artists' performance on YouTube and Spotify. Artists like Ed Sheeran, Justin Bieber, and Coldplay seem to have a strong presence on both platforms, indicating a broad appeal across different audiences. On the other hand, artists like Cocomelon might have a significant presence on YouTube due to their focus on video content, which resonates well with viewers, leading to high view counts.
#
# These insights highlight the importance of considering the nature of content and audience preferences when analyzing performance on different platforms. Artists and content creators can leverage these insights to tailor their strategies and maximize their reach and engagement across various platforms.

# %% [markdown]
# <h3> <b> <center> 12. Analyze Top 10 songs on the basis of views, comments, and likes: with titles Top 10 Songs with Most Views, Top 10 Songs with Most Comments, and Top 10 Songs with Most Likes.
#
#  </center>  </b> </h3>

# %%
top_10_views = data.nlargest(10, 'Views')
print(f"Top 10 Songs with Most Views:")
print(tabulate(top_10_views[['Artist','Track', 'Views','Comments','Likes']],floatfmt='.2f', headers='keys', tablefmt='mixed_grid', showindex=False))

top_10_comments = data.nlargest(10, 'Comments')
print("\nTop 10 Songs with Most Comments:")
print(tabulate(top_10_comments[['Artist','Track','Comments','Views','Likes']],floatfmt='.2f', headers='keys', tablefmt='mixed_grid', showindex=False))

top_10_likes = data.nlargest(10, 'Likes')
print("\nTop 10 Songs with Most Likes:")
print(tabulate(top_10_likes[['Artist','Track','Likes', 'Views','Comments']],floatfmt='.2f', headers='keys', tablefmt='mixed_grid', showindex=False))
# Out:
# Top 10 Songs with Most Views:
# ┍━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━┯━━━━━━━━━━━━┯━━━━━━━━━━━━━┑
# │ Artist       │ Track                              │         Views │   Comments │       Likes │
# ┝━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━┿━━━━━━━━━━━━━┥
# │ Luis Fonsi   │ Despacito                          │ 8079649362.00 │ 4252791.00 │ 50788652.00 │
# ├──────────────┼────────────────────────────────────┼───────────────┼────────────┼─────────────┤
# │ Daddy Yankee │ Despacito                          │ 8079646911.00 │ 4252791.00 │ 50788626.00 │
# ├──────────────┼────────────────────────────────────┼───────────────┼────────────┼─────────────┤
# │ Ed Sheeran   │ Shape of You                       │ 5908398479.00 │ 1130327.00 │ 31047780.00 │
# ├──────────────┼────────────────────────────────────┼───────────────┼────────────┼─────────────┤
# ...

# %% [markdown]
# <h3> <b> <center> 13. Make some remarks about the Top 10 Songs with Most Views, Top 10 Songs with Most Comments, and Top 10 Songs with Most Likes.  </center>  </b> </h3>

# %% [markdown]
# Taking a closer look at the top 10 songs on YouTube, we can really see what gets people buzzing and engaged. It's fascinating to see the tracks that have captured the hearts and attention of millions worldwide.
#
# First off, let's talk about views. It's no surprise that "Despacito" is a powerhouse, right? I mean, who hasn't heard that catchy tune? And then there's Ed Sheeran's "Shape of You" and Charlie Puth's "See You Again" those songs are just everywhere!
#
# Now, when it comes to comments, it's like the BTS army has taken over! Seriously, those guys are ruling the charts with tracks like "Dynamite" and "Boy With Luv." It's amazing to see the level of passion and engagement their fans bring to the table.
#
# And let's not forget about likes. "Despacito" is still holding strong, but we've also got hits from BTS, Ed Sheeran, and Halsey making waves. It's cool to see such a mix of artists and genres in the top 10 goes to show there's something for everyone on YouTube.
#
# Overall, it's clear that YouTube isn't just a platform for music it's a global stage where artists, fans, and music lovers from all walks of life come together to celebrate the songs that move us and bring us together.

# %% [markdown]
# <h3> <b> <center> 14. Analyzing the songs on the basis of Energy and Danceability and display a table of it.  </center>  </b> </h3>

# %%
top_10_energy = data.nlargest(10, 'Energy')
print("Energy, Danceability, and Acousticness for Each Track:")
print(tabulate(top_10_energy[['Artist','Track','Energy', 'Danceability']],floatfmt='.5f', headers='keys', tablefmt='mixed_grid', showindex=False))

top_10_dance = data.nlargest(10, 'Danceability')
print("Energy, Danceability, and Acousticness for Each Track:")
print(tabulate(top_10_dance[['Artist','Track','Danceability', 'Energy']],floatfmt='.5f', headers='keys', tablefmt='mixed_grid', showindex=False))
# Out:
# Energy, Danceability, and Acousticness for Each Track:
# ┍━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━┯━━━━━━━━━━━━━━━━┑
# │ Artist             │ Track                           │   Energy │   Danceability │
# ┝━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━┿━━━━━━━━━━━━━━━━┥
# │ Rain Fruits Sounds │ Rain and Thunderstorm, Pt. 3    │  1.00000 │        0.16000 │
# ├────────────────────┼─────────────────────────────────┼──────────┼────────────────┤
# │ Rain Fruits Sounds │ Rain and Thunderstorm, Pt. 4    │  1.00000 │        0.26200 │
# ├────────────────────┼─────────────────────────────────┼──────────┼────────────────┤
# │ Rain Fruits Sounds │ Rain and Thunderstorm, Pt. 7    │  1.00000 │        0.25300 │
# ├────────────────────┼─────────────────────────────────┼──────────┼────────────────┤
# │ Rain Fruits Sounds │ Rain and Thunderstorm, Pt. 6    │  1.00000 │        0.07120 │
# ...

# %% [markdown]
# <h3> <b> <center> 15. Display a bar chart of the Top 10 Songs by Stream with their Energy, Danceability, and Acousticness and make some remarks about it.
#
#   </center>  </b> </h3>

# %%
# Bar chart
top_10_stream_energy = data.nlargest(10, 'Stream')[['Track', 'Energy', 'Danceability', 'Acousticness']]
top_10_stream_energy.set_index('Track').plot(kind='bar')
plt.title('Top 10 Songs by Stream with Energy, Danceability, and Acousticness')
plt.show()

# %% [markdown]
# The data reveals interesting insights about the musical attributes of the top songs. "Shape of You" stands out with the highest danceability score, suggesting that it's particularly well-suited for getting people moving on the dance floor. This is followed by "One Dance" and "Believer," indicating their popularity for rhythmic and energetic beats.
#
# In terms of energy, "Believer" takes the lead, suggesting it has a high-intensity vibe that resonates with listeners. "Blinding Lights" and "Shape of You" closely follow, showcasing their ability to captivate audiences with energetic rhythms and powerful performances.
#
# Surprisingly, "Someone You Loved" emerges as the top song for acousticness, suggesting a more stripped-down, intimate sound compared to the upbeat tracks dominating the charts. This contrasts with the danceability and energy leaders, indicating a diverse range of musical tastes and preferences among listeners.
#
# Overall, these insights underscore the dynamic nature of music consumption, where diverse genres and styles cater to a wide range of listener preferences, from high-energy dance hits to soulful acoustic ballads.

# %% [markdown]
# <h3> <b> <center> 16. Determine the top 10 artists on the Youtube platform whose songs have more likes and display a bar chart with a title Number of Likes per Artist and make some remarks.
#
#
#
#
#
#   </center>  </b> </h3>

# %%
# Bar chart
top_10_likes_artist.plot(kind='bar')
plt.title('Number of Likes per Artist')
plt.show()

# %% [markdown]
# <h3> <b> <center> 17. Explore single releases by artists and identify top performers based on likes and display a table for each artist with their Views and Likes as the other columns.
#
#
#
#   </center>  </b> </h3>

# %%
# Filter the data for single releases
singles = data[data['Album_type'] == 'single']

# Group the data by artist and aggregate views and likes
top_performers_singles = singles.groupby('Artist')[['Views', 'Likes']].sum()

# Identify the top performers based on likes
top_likes_performers = top_likes_performers.reset_index()

print("Top Artist's Single by Views")
print(tabulate(top_likes_performers[['Artist','Views','Likes']],floatfmt='.2f', headers='keys', tablefmt='mixed_grid', showindex=False))
# Out:
# Top Artist's Single by Views
# ┍━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━┑
# │ Artist         │         Views │       Likes │
# ┝━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━┥
# │ BLACKPINK      │ 7329516365.00 │ 82959030.00 │
# ├────────────────┼───────────────┼─────────────┤
# │ Wiz Khalifa    │ 6761549938.00 │ 47790517.00 │
# ├────────────────┼───────────────┼─────────────┤
# │ Charlie Puth   │ 5870178991.00 │ 41746947.00 │
# ├────────────────┼───────────────┼─────────────┤
# │ Jubin Nautiyal │ 4525858852.00 │ 39238542.00 │
# ├────────────────┼───────────────┼─────────────┤
# │ Lil Nas X      │ 3031660205.00 │ 39103751.00 │
# ├────────────────┼───────────────┼─────────────┤
# │ Marshmello     │ 2927575201.00 │ 35843277.00 │
# ├────────────────┼───────────────┼─────────────┤
# │ Billie Eilish  │ 2435116272.00 │ 35590580.00 │
# ├────────────────┼───────────────┼─────────────┤
# │ Bizarrap       │ 1719855877.00 │ 33922836.00 │
# ├────────────────┼───────────────┼─────────────┤
# ...

# %% [markdown]
# <h3> <b> <center> 18. Make a remark about the table: Artist, Views, Likes.  </center>  </b> </h3>

# %% [markdown]
# The table paints a vivid picture of the immense popularity each artist enjoys with their single releases on platforms like YouTube. BLACKPINK reigns supreme, captivating fans worldwide with a staggering 7.3 billion views and over 82 million likes. Wiz Khalifa isn't far behind, racking up an impressive 6.7 billion views and around 47.8 million likes, showcasing his enduring appeal. Charlie Puth's music strikes a chord with audiences, earning over 5.8 billion views and approximately 41.7 million likes, underscoring his widespread recognition. Jubin Nautiyal and Lil Nas X also shine bright, capturing millions of views and likes with their tracks, signaling their rising prominence. Additionally, artists like Marshmello, Billie Eilish, Bizarrap, Selena Gomez, and Ozuna command substantial attention, with billions of views and millions of likes collectively, cementing their status as influential voices in today's music scene.

# %% [markdown]
# <h3> <b> <center> 19. Exploring compilation releases by artists and identify top performers based on views and likes and display a table for each artist with their Views and Likes as the other columns. Make some remark about the table.
#
# </center>  </b> </h3>

# %%
compilations = data[data['Album_type'] == 'compilation']

top_performers_compilations = compilations.groupby('Artist')[['Views', 'Likes']].sum().reset_index()

top_performers_compilations_sorted = top_performers_compilations.sort_values(by='Views', ascending=False)

top_20_performers = top_performers_compilations_sorted.head(20)

# Display a table for the top 20 performers with their views and likes, arranged by highest views
print("Top 20 Performers for Compilation Releases (Arranged by Views):")
print(tabulate(top_20_performers, floatfmt='.2f', headers='keys', tablefmt='mixed_grid', showindex=False))
# Out:
# Top 20 Performers for Compilation Releases (Arranged by Views):
# ┍━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━┑
# │ Artist             │         Views │       Likes │
# ┝━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━┥
# │ Shakira            │ 3463816330.00 │ 20327883.00 │
# ├────────────────────┼───────────────┼─────────────┤
# │ Ellie Goulding     │ 2283748076.00 │ 12418131.00 │
# ├────────────────────┼───────────────┼─────────────┤
# │ Idina Menzel       │ 1876738877.00 │  9018477.00 │
# ├────────────────────┼───────────────┼─────────────┤
# │ Dove Cameron       │ 1791463497.00 │ 12002533.00 │
# ├────────────────────┼───────────────┼─────────────┤
# │ DJ Luian           │ 1586161831.00 │  8457661.00 │
# ├────────────────────┼───────────────┼─────────────┤
# │ Mambo Kingz        │ 1586161639.00 │  8457653.00 │
# ├────────────────────┼───────────────┼─────────────┤
# │ PSY                │ 1539136154.00 │  8084738.00 │
# ...

# %% [markdown]
# The top 20 performers for compilation releases offer a fascinating snapshot of music's diverse landscape and the artists who've left an indelible mark on listeners worldwide. Leading the pack is Shakira, whose immense popularity shines through with billions of views, solidifying her position as a global icon. Right on her heels are Ellie Goulding and Idina Menzel, whose music has resonated deeply with fans, earning them millions of views and likes.
#
# Delving deeper into the list, we find a mix of familiar faces and unexpected surprises, showcasing the rich tapestry of musical talent. From the viral phenomenon of PSY's "Gangnam Style" to the timeless classics of Earth, Wind & Fire and George Michael, each artist brings their own unique flair to the table. Even acts like Bon Jovi and Annie Lennox, with their enduring appeal and iconic hits, continue to captivate audiences around the world.
#
# Ultimately, this collection of top performers serves as a poignant reminder of music's universal language and its ability to unite people from all walks of life. It's a testament to the lasting impact of artists who pour their hearts and souls into their craft, leaving an indelible imprint on the world through their timeless melodies and powerful lyrics.

# %% [markdown]
# <h3> <b> <center> 20. Identify the top 10 channels based on views and display a bar chart of it and make some remarks. </center>  </b> </h3>

# %%
# Bar chart
top_10_channels.plot(kind='bar')
plt.title('Top 10 Channels Based on Views')
plt.show()

# %% [markdown]
# The top 10 YouTube channels paint a vibrant picture of the platform's immense variety and influence. Leading the charge is T-series, a music giant whose staggering number of views solidifies its global status. Following closely are familiar names like LuisFonsiVEVO and CalvinHarrisVevo, showcasing the significant impact of their music on YouTube's landscape.
#
# Among this diverse mix, you'll find channels catering to different tastes and audiences. From the catchy tunes of Macklemore and Ed Sheeran to the family-friendly content of Cocomelon - Nursery Rhymes, YouTube offers something for everyone.
#
# Music remains a dominant force, as seen with channels like Hear This Music and DJSnakeVEVO. But it's not just about music; entertainment powerhouses like Bruno Mars and KatyPerryVEVO demonstrate YouTube's role in shaping pop culture.
#
# In essence, these top 10 channels embody YouTube's ability to bring people together, shaping trends and connecting creators with audiences on a global scale.
